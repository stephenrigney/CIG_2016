# %%
from bokeh.io import output_file, show, output_notebook
from bokeh.models import GeoJSONDataSource
from bokeh.plotting import figure
from bokeh.sampledata.sample_geojson import geojson
import json

# %%
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="38571d92-2cba-4470-b506-a3cfa85ad160">Loading BokehJS ...</span>
#     </div>

# %%
with open("../data/processed/dublin_ed_base.geojson", "r") as f:
    geo_source = GeoJSONDataSource(geojson=f.read())

# %%
geo_source

# %%
p = figure()
p.patches(xs='xs', ys='ys', alpha=0.9, source=geo_source)
output_file("geojson.html")
show(p)
# Out:
#     <div class="plotdiv" id="9915268f-72e7-409f-bb91-d8d5d01cd943"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9915268f-72e7-409f-bb91-d8d5d01cd943");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9915268f-72e7-409f-bb91-d8d5d01cd943' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"2c7357dd-2320-4fcb-b1b8-1941ecacdcef":{"roots":{"references":[{"attributes":{},"id":"78829433-2b18-4b7c-9e21-44edb4341899","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"2019df05-0cc4-4209-a073-39596505c715","subtype":"Figure","type":"Plot"},"ticker":{"id":"8b5cc7b4-033e-41a7-b65a-05662962fa38","type":"BasicTicker"}},"id":"4a3701bd-7e83-4550-aa39-9f09b4f5691e","type":"Grid"},{"attributes":{"callback":null},"id":"92634547-e005-4a1e-90a3-1dfa93f28d9f","type":"DataRange1d"},{"attributes":{"callback":null},"id":"cf65b3c7-3eb3-49cb-a61a-37877563574d","type":"DataRange1d"},{"attributes":{"plot":{"id":"7ad4cf9c-903d-4afa-bc37-0f39ba71aec7","subtype":"Figure","type":"Plot"}},"id":"633e894d-2492-4a38-8238-7f3ee755a643","type":"HelpTool"},{"attributes":{},"id":"ff931ab5-ef2e-4748-bd19-11be87de1c7b","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"06a2df66-743f-4009-a8f5-a3a33f50e181","type":"BasicTickFormatter"},"plot":{"id":"45a8d472-8040-4838-9f1a-09e507fdf7ef","subtype":"Figure","type":"Plot"},"ticker":{"id":"b20f524c-b6b6-46aa-a4da-dcecb4350365","type":"BasicTicker"}},"id":"8049e1e0-e3de-45e6-9677-9d389fb65e0a","type":"LinearAxis"},{"attributes":{"overlay":{"id":"2453a9ab-2e24-4c30-b41f-1a002a294b5e","type":"BoxAnnotation"},"plot":{"id":"45a8d472-8040-4838-9f1a-09e507fdf7ef","subtype":"Figure","type":"Plot"}},"id":"78dc335d-1bf8-453b-b63b-76aaed50ce8a","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"c630b28f-d9e5-4f32-ae7b-03b2f65072d9","subtype":"Figure","type":"Plot"},"ticker":{"id":"16489ce6-ab03-46e6-ae3f-15c55a003180","type":"BasicTicker"}},"id":"14ea4c1a-f2d3-413c-bd84-beec9f1b2d51","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c7964b80-b3f9-4c2e-9af7-4329e895b74a","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4895ba03-13b8-4088-8850-77710bb6a078","type":"Circle"},{"attributes":{"below":[{"id":"0f707005-9610-4501-b0de-1bee0928fc83","type":"LinearAxis"}],"left":[{"id":"f2dff579-223b-4237-8546-a9d5f4953bec","type":"LinearAxis"}],"renderers":[{"id":"0f707005-9610-4501-b0de-1bee0928fc83","type":"LinearAxis"},{"id":"7f5ab04a-db27-418e-b5ce-f56d1890e382","type":"Grid"},{"id":"f2dff579-223b-4237-8546-a9d5f4953bec","type":"LinearAxis"},{"id":"1042163d-31bc-4000-b018-0f4535e50442","type":"Grid"},{"id":"cf8be264-9389-49a1-b183-aa6ccdc14299","type":"BoxAnnotation"},{"id":"fc0c1f64-87fb-413a-816f-e7f20321fe52","type":"GlyphRenderer"}],"tool_events":{"id":"af7756cc-8a62-442b-a3f5-205b53dc8f48","type":"ToolEvents"},"tools":[{"id":"d6815cc4-b7bc-492d-97e0-af402ffc774f","type":"PanTool"},{"id":"cc317f18-7814-4490-ae8a-1c6003ccf572","type":"WheelZoomTool"},{"id":"9cd59a5a-a87a-4145-9cb6-6336dd282a9b","type":"BoxZoomTool"},{"id":"df291c5a-8cb8-4d7f-8e5c-38389a442076","type":"PreviewSaveTool"},{"id":"bb5a3497-ef80-4ca1-9810-43b8014299c6","type":"ResizeTool"},{"id":"602760f0-c691-4e2f-afcb-dda09cffa691","type":"ResetTool"},{"id":"ac589b46-2428-470d-8594-674549731936","type":"HelpTool"}],"x_range":{"id":"43bcdebe-6304-469e-8e56-1fe0188fa840","type":"DataRange1d"},"y_range":{"id":"80097310-2749-411f-973c-e7e678090eee","type":"DataRange1d"}},"id":"c8643ea5-b5ea-420f-adb5-275015ea904d","subtype":"Figure","type":"Plot"},{"attributes":{"overlay":{"id":"37f31fbf-2f49-4157-b1c3-1b7d6555d2e9","type":"BoxAnnotation"},"plot":{"id":"7ad4cf9c-903d-4afa-bc37-0f39ba71aec7","subtype":"Figure","type":"Plot"}},"id":"b5d39ef2-df66-41be-9679-8653641ca4c8","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"1a313efc-0367-435a-9bc4-63686576c55e","type":"DataRange1d"},{"attributes":{},"id":"8b5cc7b4-033e-41a7-b65a-05662962fa38","type":"BasicTicker"},{"attributes":{"plot":{"id":"45a8d472-8040-4838-9f1a-09e50 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[22]</strong>&gt;</code></p>

# %% [markdown]
# now what?
